# %% [markdown]
# **Q1. Data Understanding**
# There are multiple issues in respect to quality of data:
# - Firstly there are duplicate order ID O101 as it appeared twice.
#  - Apart from that the amount column has irregularities  as it do not follow a standard format, and also has null values.
# - Additionally the date format is also not consistent

# %% [markdown]
# **Q2. Primary Key Validation**
#
# - Yes the datset violates the Primary key rule as primary must  be unique for every record and order Id  O101 has repeated twice, which is violation.

# %% [markdown]
# **Q3. Missing Value Analysis**
# - a) Sales_amount contains the missing value, the affected row is with Order_ID O101
# - b) Missing values can lead to incorrect calculations and incomplete reports.

# %% [markdown]
# **Q4. Data Type Validation**
#
# - The row with Order_ID O104 will fail the numerical validation because the sales_amount cell contains the amount in words that is Three Thousands.
# - It will generate an error is the column has been defined as DECIMAL in SQL.

# %% [markdown]
# **Q5. Date Format Consistency**
#
# - a) Date formats present: DD-MM-YYYY and YYYY/MM/DD
# - b) Different date formats can cause parsing errors and incorrect date values during loading.

# %% [markdown]
# **Q6. Load Readiness Decision**
#
# - a) No, the dataset should not be loaded directly.
# - b) Reason being that it has a duplicate primary key , that will cause an error, sales amount has missing values and lacks format standardization for date as well.

# %% [markdown]
# **Q7. Pre-Load Validation Checklist**
#
# - Check for duplicate Order_ID values.
# - Check for missing values.
# - Validate numeric fields.
# - Validate date formats.
# - Verify primary key uniqueness.

# %% [markdown]
# **Q8. Cleaning Strategy**
#
# - Remove duplicate record O101.
# - Handle missing Sales_Amount for O102.
# - Convert "Three Thousand" to 3000.
# - Standardize all dates into one format.
# - Validate data before loading.

# %% [markdown]
# **Q9. Loading Strategy Selection**
#
# - a) Incremental Load.
# - b) Since this is daily sales data, only new records need to be loaded each day, making Incremental Load faster and more efficient.

# %% [markdown]
# **Q10. BI Impact Scenario**
#
# a) Total Sales KPI may be incorrect because of duplicate records, missing values, and invalid sales amounts.
#
# b) Misleading records:
# - O101 (duplicate record)
# - O102 (missing Sales_Amount)
# - O104 ("Three Thousand")
#
# c) BI tools usually display the data they receive and may not automatically identify duplicates, missing values, or incorrect data types.
