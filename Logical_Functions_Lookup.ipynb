# %% [markdown]
# **Question 1: Write a formula to check if the marks in cell are greater than or equal to 40. If yes, return B2 "Fail"**
#
#     =IF(B2>=40,"Pass", "Fail")
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 2: A company gives a bonus if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not.**
#
#     =IF(AND(B10>40000,C10>=90),"Eligible","Not Eligible")
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 3: Write a nested IF formula:**
# **If marks in B2 are ≥ 90 → "A” , ≥ 75 →"B"  , ≥ 50 → "C" , otherwise  "Fail"**
#
#     =IF(B16>=90, "A",IF(B16>=75, "B",IF(B16>=50, "C","Fail")))
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question4: Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?**
#
#     =VLOOKUP(E23,A23:C26,3,)
# Vlokup function was used because it provides exact match in a table, that was suitable for finding values in another column based on the match. Also as the table was verticle vlookup was the best way to find the value.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 5: A company has set the following commission structure for its sales team**
#
#     =VLOOKUP(45000,A29:B32,2,TRUE)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question6: The HR department maintains the following leave records of employees bonus or not.**
#
#     =IF(C35>B35,"Ok", "Exceeded")
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Question 7: Find the salary of EmpID = E105 using INDEX-MATCH Function**
#
# Answer: Concept not clear

# %% [markdown]
# **Question 8: Use the XLOOKUP function to find the Department of the employee with Emp ID = E303**
#
#     =xlookup(G3,G2:G5,H2:H5)
#
# ![image.png](data:image/png;base64,...)
